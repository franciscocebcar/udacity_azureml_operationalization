# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.31.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-152512
# aml-quickstarts-152512
# southcentralus
# b968fb36-f06a-4c76-a15f-afab68ae7667

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'automl_bankmarketing'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: automl_bankmarketing,
# Workspace: quick-starts-ws-152512)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "automl"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 60,
    "max_concurrent_iterations": 9,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [6b10b3fa][80251fdf-313e-4481-a009-77563b92f322], (This step will run and generate new outputs)
# Submitted PipelineRun b81f17bb-1072-4ce8-a6d0-ff1af74af205
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/b81f17bb-1072-4ce8-a6d0-ff1af74af205?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-152512/workspaces/quick-starts-ws-152512&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: b81f17bb-1072-4ce8-a6d0-ff1af74af205
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/b81f17bb-1072-4ce8-a6d0-ff1af74af205?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-152512/workspaces/quick-starts-ws-152512&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# PipelineRun Status: Running
#
#
# StepRunId: 426360f0-fd94-41bf-943e-af6d7fd2c373
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/426360f0-fd94-41bf-943e-af6d7fd2c373?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-152512/workspaces/quick-starts-ws-152512&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '426360f0-fd94-41bf-943e-af6d7fd2c373', 'target': 'automl', 'status': 'Completed', 'startTimeUtc': '2021-07-26T00:04:08.541845Z', 'endTimeUtc': '2021-07-26T00:35:16.276342Z', 'properties': {'ContentSnapshotId': 'cf69ed9d-d25c-490a-8dd5-47f5acab73b4', 'StepType': 'AutoMLStep', 'azureml.moduleid': '80251fdf-313e-4481-a009-77563b92f322', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '6b10b3fa', 'azureml.pipelinerunid': 'b81f17bb-1072-4ce8-a6d0-ff1af74af205', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'automl', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "b968fb36-f06a-4c76-a15f-afab68ae7667", "resource_group": "aml-quickstarts-152512", "workspace_name": "quick-starts-ws-152512", "region": "southcentralus", "compute_target": "automl", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": false, "enable_code_generation": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "test_size": 0.0, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 9, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 60, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["SGD", "ExtremeRandomTrees", "DecisionTree", "LightGBM", "GradientBoosting", "TensorFlowLinearClassifier", "XGBoostClassifier", "LinearSVM", "TensorFlowDNN", "BernoulliNaiveBayes", "AveragedPerceptronClassifier", "LogisticRegression", "RandomForest", "MultinomialNaiveBayes", "SVM", "KNN"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "save_mlflow": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"d135a290-a78a-4a01-99fd-b0d9ecada149\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'cf69ed9d-d25c-490a-8dd5-47f5acab73b4', 'SetupRunId': '426360f0-fd94-41bf-943e-af6d7fd2c373_setup', 'SetupRunContainerId': 'dcid.426360f0-fd94-41bf-943e-af6d7fd2c373_setup', 'ClientSdkVersion': '1.31.0',  ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'b81f17bb-1072-4ce8-a6d0-ff1af74af205', 'status': 'Completed', 'startTimeUtc': '2021-07-26T00:03:50.269142Z', 'endTimeUtc': '2021-07-26T00:36:25.065997Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg152512.blob.core.windows.net/azureml/ExperimentRun/dcid.b81f17bb-1072-4ce8-a6d0-ff1af74af205/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Jhw04CMt2LzGOTsFr%2BwxC3VfmgEu%2F9oQJBlbswBGtFs%3D&st=2021-07-25T23%3A53%3A53Z&se=2021-07-26T08%3A03%3A53Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg152512.blob.core.windows.net/azureml/ExperimentRun/dcid.b81f17bb-1072-4ce8-a6d0-ff1af74af205/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=dSEF%2FPjGao7tGVtiQQ0sDELR6gGII3%2Fxl7ccN5eG9wY%3D&st=2021-07-25T23%3A53%3A53Z&se=2021-07-26T08%3A03%3A53Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg152512.blob.core.windows.net/azureml/ExperimentRun/dcid.b81f17bb-1072-4ce8-a6d0-ff1af74af205/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=ffClf8BXgjOixicwo81h14pK6YSMY8%2BWz0j82on7PCg%3D&st=2021-07-25T23%3A53%3A53Z&se=2021-07-26T08%3A03%3A53Z&sp=r'}, 'submittedBy': 'ODL_User 152512'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/426360f0-fd94-41bf-943e-af6d7fd2c373/metrics_data
# Downloaded azureml/426360f0-fd94-41bf-943e-af6d7fd2c373/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_53  \
# average_precision_score_micro                       [0.9791576752709963]
# log_loss                                            [0.1890673655834418]
# average_precision_score_macro                       [0.8078566650651889]
# matthews_correlation                               [0.48557165516749917]
# precision_score_weighted                            [0.8989983209331218]
# AUC_macro                                           [0.9390776460737948]
# recall_score_macro                                  [0.7125806015408069]
# recall_score_weighted                               [0.9080424886191198]
# AUC_weighted                                        [0.9390776460737951]
# balanced_accuracy                                   [0.7125806015408069]
# weighted_accuracy                                   [0.9565703880260812]
# accuracy                                            [0.9080424886191198]
# precision_score_macro                               [0.7772828642326102]
# average_precision_score_weighted                    [0.9508997499056375]
# precision_score_micro                               [0.9080424886191198]
# f1_score_micro                                        [0.90804248861912]
# AUC_micro                                           [0.9781203414379169]
# norm_macro_recall                                  [0.42516120308161387]
# f1_score_weighted                                   [0.9019838447775502]
# recall_score_micro                                  [0.9080424886191198]
# f1_score_macro                                      [0.7389106626418276]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_12  \
# average_precision_score_micro                       [0.8191601011872747]
# log_loss                                            [0.5802485087110388]
# average_precision_score_macro                       [0.7243556744558586]
# matthews_correlation                                 [0.372189079524968]
# precision_score_weighted                            [0.8858609831802674]
# AUC_macro                                           [0.8662486778661362]
# recall_score_macro                                  [0.7612740276411649]
# recall_score_weighted                               [0.7842185128983308]
# AUC_weighted                                        [0.8662486778661362]
# balanced_accuracy                                   [0.7612740276411649]
# weighted_accuracy                                   [0.7899150079498605]
# accuracy                                            [0.7842185128983308]
# precision_score_macro                               [0.6325473413567665]
# average_precision_score_weighted                    [0.9233942211470734]
# precision_score_micro                               [0.7842185128983308]
# f1_score_micro                                      [0.7842185128983308]
# AUC_micro                                           [0.8488145693686805]
# norm_macro_recall                                   [0.5225480552823298]
# f1_score_weighted                                   [0.8180947534295128]
# recall_score_micro                                  [0.7842185128983308]
# f1_score_macro                                       [0.649241835226331]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_3  \
# average_precision_score_micro                      [0.8611821854804776]
# log_loss                                           [0.5044048529523177]
# average_precision_score_macro                      [0.7519177653159639]
# matthews_correlation                               [0.4154931451686474]
# precision_score_weighted                           [0.8947705166795193]
# AUC_macro                                          [0.8926066089095613]
# recall_score_macro                                 [0.7887762643860206]
# recall_score_weighted                              [0.8015174506828529]
# AUC_weighted                                       [0.8926066089095613]
# balanced_accuracy                                  [0.7887762643860206]
# weighted_accuracy                                  [0.8046807425970985]
# accuracy                                           [0.8015174506828529]
# precision_score_macro                              [0.6494535519125683]
# average_precision_score_weighted                    [0.933101324369824]
# precision_score_micro                              [0.8015174506828529]
# f1_score_micro                                      [0.801517450682853]
# AUC_micro                                          [0.8758875474635087]
# norm_macro_recall                                  [0.5775525287720411]
# f1_score_weighted                                  [0.8319337666761629]
# recall_score_micro                                 [0.8015174506828529]
# f1_score_macro                                     [0.6719038901434595]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_2  \
# average_precision_score_micro                       [0.966619309594672]
# log_loss                                           [0.2477791553685806]
# average_precision_score_macro                      [0.7408752292690819]
# matthews_correlation                                              [0.0]
# precision_score_weighted                            [0.788565560086672]
# AUC_macro                                          [0.8947308218810144]
# recall_score_macro                                                [0.5]
# recall_score_weighted                              [0.8880121396054628]
# AUC_weighted                                       [0.8947308218810143]
# balanced_accuracy                                                 [0.5]
# weighted_accuracy                                  [0.9843450583187134]
# accuracy                                           [0.8880121396054628]
# precision_score_macro                              [0.4440060698027314]
# average_precision_score_weighted                   [0.9295271407424454]
# precision_score_micro                              [0.8880121396054628]
# f1_score_micro                                     [0.8880121396054628]
# AUC_micro                                          [0.9665213997388787]
# norm_macro_recall                                                 [0.0]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_micro                                 [0.8880121396054628]
# f1_score_macro                                     [0.4703423886834914]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_7  \
# average_precision_score_micro                      [0.9560830573100224]
# log_loss                                          [0.28096715368634806]
# average_precision_score_macro                      [0.7184360653300451]
# matthews_correlation                                              [0.0]
# precision_score_weighted                            [0.788565560086672]
# AUC_macro                                          [0.8429731016380567]
# recall_score_macro                                                [0.5]
# recall_score_weighted                              [0.8880121396054628]
# AUC_weighted                                       [0.8429731016380567]
# balanced_accuracy                                                 [0.5]
# weighted_accuracy                                  [0.9843450583187134]
# accuracy                                           [0.8880121396054628]
# precision_score_macro                              [0.4440060698027314]
# average_precision_score_weighted                    [0.917761998305009]
# precision_score_micro                              [0.8880121396054628]
# f1_score_micro                                     [0.8880121396054628]
# AUC_micro                                          [0.9562271432551734]
# norm_macro_recall                                                 [0.0]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_micro                                 [0.8880121396054628]
# f1_score_macro                                     [0.4703423886834914]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_50  \
# average_precision_score_micro                       [0.9797540509161158]
# log_loss                                            [0.1849465615155293]
# average_precision_score_macro                       [0.8093072818478683]
# matthews_correlation                                [0.5216286298277554]
# precision_score_weighted                            [0.9051980543721705]
# AUC_macro                                           [0.9427773054217213]
# recall_score_macro                                  [0.7445642005975768]
# recall_score_weighted                               [0.9101669195751139]
# AUC_weighted                                        [0.9427773054217213]
# balanced_accuracy                                   [0.7445642005975768]
# weighted_accuracy                                   [0.9512815952194833]
# accuracy                                            [0.9101669195751139]
# precision_score_macro                               [0.7781441711329087]
# average_precision_score_weighted                    [0.9516218532207614]
# precision_score_micro                               [0.9101669195751139]
# f1_score_micro                                      [0.9101669195751139]
# AUC_micro                                            [0.978747769301443]
# norm_macro_recall                                  [0.48912840119515355]
# f1_score_weighted                                   [0.9072831557855964]
# recall_score_micro                                  [0.9101669195751139]
# f1_score_macro                                      [0.7598074755896701]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_13  \
# average_precision_score_micro                       [0.9766643355999638]
# log_loss                                           [0.33655623031442766]
# average_precision_score_macro                       [0.7985126174047921]
# matthews_correlation                                [0.3976739324324451]
# precision_score_weighted                            [0.8929725418691179]
# AUC_macro                                           [0.9308878256246677]
# recall_score_macro                                  [0.6227454260188535]
# recall_score_weighted                               [0.9062215477996965]
# AUC_weighted                                        [0.9308878256246675]
# balanced_accuracy                                   [0.6227454260188535]
# weighted_accuracy                                   [0.9766010009385309]
# accuracy                                            [0.9062215477996965]
# precision_score_macro                                [0.822098675416211]
# average_precision_score_weighted                     [0.947605275820125]
# precision_score_micro                               [0.9062215477996965]
# f1_score_micro                                      [0.9062215477996965]
# AUC_micro                                           [0.9758990146932517]
# norm_macro_recall                                  [0.24549085203770704]
# f1_score_weighted                                    [0.885603431576398]
# recall_score_micro                                  [0.9062215477996965]
# f1_score_macro                                      [0.6650154684677185]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_10  \
# average_precision_score_micro                        [0.877225511911242]
# log_loss                                            [0.4776995500652426]
# average_precision_score_macro                       [0.7582588451210346]
# matthews_correlation                               [0.39686994500685197]
# precision_score_weighted                            [0.9112378010158444]
# AUC_macro                                           [0.9052194418048076]
# recall_score_macro                                  [0.8099651382706582]
# recall_score_weighted                               [0.6898330804248862]
# AUC_weighted                                        [0.9052194418048075]
# balanced_accuracy                                   [0.8099651382706582]
# weighted_accuracy                                   [0.6600075399789621]
# accuracy                                            [0.6898330804248862]
# precision_score_macro                                [0.627035054755262]
# average_precision_score_weighted                    [0.9357758554944468]
# precision_score_micro                               [0.6898330804248862]
# f1_score_micro                                      [0.6898330804248862]
# AUC_micro                                           [0.8616547350678478]
# norm_macro_recall                                   [0.6199302765413164]
# f1_score_weighted                                   [0.7471034449165869]
# recall_score_micro                                  [0.6898330804248862]
# f1_score_macro                                      [0.6000750091683151]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_0  \
# average_precision_score_micro                      [0.9806603102489483]
# log_loss                                          [0.17775706110025447]
# average_precision_score_macro                      [0.8151093723721079]
# matthews_correlation                               [0.5323740218566827]
# precision_score_weighted                           [0.9072720074188747]
# AUC_macro                                          [0.9450464668693166]
# recall_score_macro                                 [0.7513392683482543]
# recall_score_weighted                              [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# balanced_accuracy                                  [0.7513392683482543]
# weighted_accuracy                                  [0.9514937218005303]
# accuracy                                           [0.9116843702579667]
# precision_score_macro                              [0.7819118765348991]
# average_precision_score_weighted                   [0.9531771295804466]
# precision_score_micro                              [0.9116843702579667]
# f1_score_micro                                     [0.9116843702579667]
# AUC_micro                                           [0.979695082216353]
# norm_macro_recall                                  [0.5026785366965085]
# f1_score_weighted                                  [0.9091539479147899]
# recall_score_micro                                 [0.9116843702579667]
# f1_score_macro                                     [0.7653697272147331]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_4  ...  \
# average_precision_score_micro                      [0.9666606505718869]  ...
# log_loss                                           [0.2696919468469947]  ...
# average_precision_score_macro                      [0.7243799032676478]  ...
# matthews_correlation                                              [0.0]  ...
# precision_score_weighted                            [0.788565560086672]  ...
# AUC_macro                                          [0.8889921588894631]  ...
# recall_score_macro                                                [0.5]  ...
# recall_score_weighted                              [0.8880121396054628]  ...
# AUC_weighted                                       [0.8889921588894633]  ...
# balanced_accuracy                                                 [0.5]  ...
# weighted_accuracy                                  [0.9843450583187134]  ...
# accuracy                                           [0.8880121396054628]  ...
# precision_score_macro                              [0.4440060698027314]  ...
# average_precision_score_weighted                   [0.9262690069805208]  ...
# precision_score_micro                              [0.8880121396054628]  ...
# f1_score_micro                                     [0.8880121396054628]  ...
# AUC_micro                                          [0.9653800189278371]  ...
# norm_macro_recall                                                 [0.0]  ...
# f1_score_weighted                                  [0.8353395018439429]  ...
# recall_score_micro                                 [0.8880121396054628]  ...
# f1_score_macro                                     [0.4703423886834914]  ...
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_47  \
# average_precision_score_micro                       [0.9794868805992267]
# log_loss                                           [0.31912071497881517]
# average_precision_score_macro                       [0.8050074476567731]
# matthews_correlation                                [0.5242574455664286]
# precision_score_weighted                            [0.9060269508317579]
# AUC_macro                                            [0.940594742584473]
# recall_score_macro                                  [0.7398397138448487]
# recall_score_weighted                               [0.9122913505311078]
# AUC_weighted                                         [0.940594742584473]
# balanced_accuracy                                   [0.7398397138448487]
# weighted_accuracy                                   [0.9551064271824635]
# accuracy                                            [0.9122913505311078]
# precision_score_macro                               [0.7864891147777485]
# average_precision_score_weighted                    [0.9503695894267387]
# precision_score_micro                               [0.9122913505311078]
# f1_score_micro                                      [0.9122913505311078]
# AUC_micro                                           [0.9785327932836113]
# norm_macro_recall                                   [0.4796794276896974]
# f1_score_weighted                                   [0.9084088618605763]
# recall_score_micro                                  [0.9122913505311078]
# f1_score_macro                                      [0.7602368688673142]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_59  \
# average_precision_score_micro                       [0.9802480231193443]
# log_loss                                           [0.21094115552731701]
# average_precision_score_macro                       [0.8175938098375114]
# matthews_correlation                                 [0.523019383799085]
# precision_score_weighted                            [0.9070402806185162]
# AUC_macro                                             [0.94254853690027]
# recall_score_macro                                  [0.7239574360883732]
# recall_score_weighted                               [0.9156297420333839]
# AUC_weighted                                          [0.94254853690027]
# balanced_accuracy                                   [0.7239574360883732]
# weighted_accuracy                                   [0.9632167909513815]
# accuracy                                            [0.9156297420333839]
# precision_score_macro                               [0.8053585545175117]
# average_precision_score_weighted                    [0.9534021479092283]
# precision_score_micro                               [0.9156297420333839]
# f1_score_micro                                      [0.9156297420333839]
# AUC_micro                                           [0.9793061174677226]
# norm_macro_recall                                   [0.4479148721767463]
# f1_score_weighted                                   [0.9091624341480234]
# recall_score_micro                                  [0.9156297420333839]
# f1_score_macro                                      [0.7560429317140727]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_52  \
# average_precision_score_micro                       [0.9801965514804069]
# log_loss                                           [0.18336134731730297]
# average_precision_score_macro                       [0.8149276637285758]
# matthews_correlation                                [0.5264365575296669]
# precision_score_weighted                            [0.9064419404986112]
# AUC_macro                                           [0.9431190689213795]
# recall_score_macro                                  [0.7411947273949842]
# recall_score_weighted                               [0.9125948406676783]
# AUC_weighted                                        [0.9431190689213795]
# balanced_accuracy                                   [0.7411947273949842]
# weighted_accuracy                                    [0.955148852498673]
# accuracy                                            [0.9125948406676783]
# precision_score_macro                               [0.7872528061629692]
# average_precision_score_weighted                    [0.9529182178519179]
# precision_score_micro                               [0.9125948406676783]
# f1_score_micro                                      [0.9125948406676783]
# AUC_micro                                            [0.979213090142097]
# norm_macro_recall                                   [0.4823894547899683]
# f1_score_weighted                                   [0.9087900123862012]
# recall_score_micro                                  [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_63  \
# average_precision_score_micro                       [0.9800004952735442]
# log_loss                                           [0.18332088703685712]
# average_precision_score_macro                       [0.8139823443137786]
# matthews_correlation                                 [0.511618333843717]
# precision_score_weighted                            [0.9039392237084284]
# AUC_macro                                           [0.9421053557767293]
# recall_score_macro                                  [0.7276566323421265]
# recall_score_weighted                               [0.9116843702579667]
# AUC_weighted                                        [0.9421053557767293]
# balanced_accuracy                                   [0.7276566323421265]
# weighted_accuracy                                   [0.9573734797163872]
# accuracy                                            [0.9116843702579667]
# precision_score_macro                               [0.7874431076662567]
# average_precision_score_weighted                    [0.9525882965998462]
# precision_score_micro                               [0.9116843702579667]
# f1_score_micro                                      [0.9116843702579667]
# AUC_micro                                           [0.9790150616766564]
# norm_macro_recall                                  [0.45531326468425304]
# f1_score_weighted                                   [0.9065686230152441]
# recall_score_micro                                  [0.9116843702579667]
# f1_score_macro                                      [0.7526749089018152]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_55  \
# average_precision_score_micro                       [0.9791295601207484]
# log_loss                                           [0.18892457853290068]
# average_precision_score_macro                       [0.8060655213771437]
# matthews_correlation                                [0.4854780339853703]
# precision_score_weighted                            [0.8988861939650942]
# AUC_macro                                           [0.9391045055358278]
# recall_score_macro                                  [0.7135938515912842]
# recall_score_weighted                               [0.9077389984825494]
# AUC_weighted                                        [0.9391045055358276]
# balanced_accuracy                                   [0.7135938515912842]
# weighted_accuracy                                   [0.9559399869182862]
# accuracy                                            [0.9077389984825494]
# precision_score_macro                               [0.7758610790132849]
# average_precision_score_weighted                    [0.9505019593601822]
# precision_score_micro                               [0.9077389984825494]
# f1_score_micro                                      [0.9077389984825494]
# AUC_micro                                           [0.9780915121775993]
# norm_macro_recall                                   [0.4271877031825684]
# f1_score_weighted                                   [0.9018833279732202]
# recall_score_micro                                  [0.9077389984825494]
# f1_score_macro                                      [0.7391338769693612]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_48  \
# average_precision_score_micro                       [0.9779507448934874]
# log_loss                                           [0.23432701644308443]
# average_precision_score_macro                        [0.807677125637279]
# matthews_correlation                                 [0.536641723383102]
# precision_score_weighted                            [0.9080971927496306]
# AUC_macro                                           [0.9357577239477111]
# recall_score_macro                                  [0.7540492954485252]
# recall_score_weighted                               [0.9122913505311078]
# AUC_weighted                                        [0.9357577239477111]
# balanced_accuracy                                   [0.7540492954485252]
# weighted_accuracy                                   [0.9515785724329492]
# accuracy                                            [0.9122913505311078]
# precision_score_macro                               [0.7833941526654777]
# average_precision_score_weighted                     [0.950416657594158]
# precision_score_micro                               [0.9122913505311078]
# f1_score_micro                                      [0.9122913505311078]
# AUC_micro                                           [0.9769045848195061]
# norm_macro_recall                                   [0.5080985908970503]
# f1_score_weighted                                    [0.909897948730869]
# recall_score_micro                                  [0.9122913505311078]
# f1_score_macro                                      [0.7675740323771516]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_56  \
# average_precision_score_micro                       [0.9800045982236802]
# log_loss                                            [0.1812226247428256]
# average_precision_score_macro                       [0.8091251563962392]
# matthews_correlation                                [0.5154931126518896]
# precision_score_weighted                            [0.9043597378614506]
# AUC_macro                                           [0.9431639890561585]
# recall_score_macro                                  [0.7344196596443067]
# recall_score_weighted                               [0.9110773899848255]
# AUC_weighted                                        [0.9431639890561585]
# balanced_accuracy                                   [0.7344196596443067]
# weighted_accuracy                                   [0.9549367259176257]
# accuracy                                            [0.9110773899848255]
# precision_score_macro                               [0.7833946922313813]
# average_precision_score_weighted                     [0.951637686800854]
# precision_score_micro                               [0.9110773899848255]
# f1_score_micro                                      [0.9110773899848255]
# AUC_micro                                            [0.979001798374785]
# norm_macro_recall                                  [0.46883931928861333]
# f1_score_weighted                                   [0.9068775925449892]
# recall_score_micro                                  [0.9110773899848255]
# f1_score_macro                                      [0.7556257326342737]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_60  \
# average_precision_score_micro                        [0.979762226532063]
# log_loss                                           [0.32346484909435325]
# average_precision_score_macro                        [0.817350862252727]
# matthews_correlation                                [0.4876160926631804]
# precision_score_weighted                            [0.9006160787316793]
# AUC_macro                                           [0.9404534988617145]
# recall_score_macro                                  [0.7024481010360343]
# recall_score_weighted                               [0.9110773899848255]
# AUC_weighted                                        [0.9404534988617145]
# balanced_accuracy                                   [0.7024481010360343]
# weighted_accuracy                                   [0.9628743991040325]
# accuracy                                            [0.9110773899848255]
# precision_score_macro                               [0.7936177872344998]
# average_precision_score_weighted                    [0.9531133232455068]
# precision_score_micro                               [0.9110773899848255]
# f1_score_micro                                      [0.9110773899848255]
# AUC_micro                                           [0.9788080989037052]
# norm_macro_recall                                  [0.40489620207206856]
# f1_score_weighted                                   [0.9029408969388653]
# recall_score_micro                                  [0.9110773899848255]
# f1_score_macro                                      [0.7365007951906997]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_69  \
# average_precision_score_micro                       [0.9815285297586368]
# log_loss                                             [0.192701769295887]
# average_precision_score_macro                       [0.8257878977617761]
# matthews_correlation                                [0.5419130472554575]
# precision_score_weighted                            [0.9095173265049789]
# AUC_macro                                           [0.9475527325334772]
# recall_score_macro                                  [0.7486533221449782]
# recall_score_weighted                               [0.9153262518968134]
# AUC_weighted                                         [0.947552732533477]
# balanced_accuracy                                   [0.7486533221449782]
# weighted_accuracy                                   [0.9567066319277294]
# accuracy                                            [0.9153262518968134]
# precision_score_macro                               [0.7952602324517412]
# average_precision_score_weighted                    [0.9557924902442887]
# precision_score_micro                               [0.9153262518968134]
# f1_score_micro                                      [0.9153262518968134]
# AUC_micro                                           [0.9806404608997399]
# norm_macro_recall                                   [0.4973066442899563]
# f1_score_weighted                                   [0.9117023352928492]
# recall_score_micro                                  [0.9153262518968134]
# f1_score_macro                                      [0.7691430313492165]
#
#                                  426360f0-fd94-41bf-943e-af6d7fd2c373_70
# average_precision_score_micro                       [0.9807176498827566]
# log_loss                                           [0.20115738641738293]
# average_precision_score_macro                       [0.8145493145253093]
# matthews_correlation                               [0.49481749762461336]
# precision_score_weighted                            [0.9008301085603038]
# AUC_macro                                           [0.9452650473189625]
# recall_score_macro                                  [0.7169874056908716]
# recall_score_weighted                               [0.9095599393019727]
# AUC_weighted                                        [0.9452650473189624]
# balanced_accuracy                                   [0.7169874056908716]
# weighted_accuracy                                    [0.957370490398714]
# accuracy                                            [0.9095599393019727]
# precision_score_macro                               [0.7820951234196267]
# average_precision_score_weighted                    [0.9530631259965966]
# precision_score_micro                               [0.9095599393019727]
# f1_score_micro                                      [0.9095599393019727]
# AUC_micro                                           [0.9797624118946028]
# norm_macro_recall                                   [0.4339748113817432]
# f1_score_weighted                                   [0.9036743811613195]
# recall_score_micro                                  [0.9095599393019727]
# f1_score_macro                                      [0.7435746772714262]
#
# [21 rows x 66 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/426360f0-fd94-41bf-943e-af6d7fd2c373/model_data
# Downloaded azureml/426360f0-fd94-41bf-943e-af6d7fd2c373/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=False, is_onnx_compatible=False, observer=None, task='classification', working_dir='/m...
# ), random_state=None, reg_alpha=0.631578947368421, reg_lambda=0.15789473684210525, subsample=0.9405263157894738))], verbose=False))], flatten_transform=None, weights=[0.07692307692307693, 0.15384615384615385, 0.15384615384615385, 0.07692307692307693, 0.07692307692307693, 0.15384615384615385, 0.15384615384615385, 0.15384615384615385]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(
#       task='classification',
#       is_onnx_compatible=False,
#       enable_feature_sweeping=True,
#       enable_dnn=False,
#       force_text_dnn=False,
#       feature_sweeping_timeout=86400,
#       featurization_config=None,
#       is_cross_validation=False,
#       feature_sweeping_config={}
#   )),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(
#       estimators=[('43', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.7, eta=0.3, gamma=0, max_depth=10, max_leaves=0, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_feature...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.9791666666666667, reg_lambda=2.0833333333333335, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('28', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.7, eta=0.3, max_depth=3, max_leaves=0, n_estimators=600, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dat...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=2.0833333333333335, reg_lambda=1.4583333333333335, subsample=0.7, tree_method='auto'))],
#                verbose=False)), ('0', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(min_data_in_leaf=20, n_jobs=1, problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=2,
#           dataset_num_categorical=0,
#           dataset_categoricals=None,
#           pipeline_categoricals=None,
#           dataset_y_std=None,
#           dataset_uid=None,
#           subsamplin...
#           subsampling_schedule='hyperband_clip',
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None))],
#                verbose=False)), ('41', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.9, eta=0.01, max_depth=4, max_leaves=0, n_estimators=800, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           da...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.0416666666666667, reg_lambda=0.3125, subsample=0.8, tree_method='auto'))],
#                verbose=False)), ('46', Pipeline(memory=None,
#                steps=[('sparsenormalizer', Normalizer(copy=True, norm='max')),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bylevel=1, colsample_bytree=1, eta=0.3, gamma=0, grow_policy='lossguide', max_bin=255, max_depth=5, max_leaves=15, n_estimators=400, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=296...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0.3125, reg_lambda=1.4583333333333335, subsample=1, tree_method='hist'))],
#                verbose=False)), ('23', Pipeline(memory=None,
#                steps=[('sparsenormalizer', Normalizer(copy=True, norm='max')),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.8, eta=0.3, gamma=1, max_depth=8, max_leaves=3, n_estimators=600, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=2,
#           dataset_num_c...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0.625, reg_lambda=2.3958333333333335, subsample=0.8, tree_method='auto'))],
#                verbose=False)), ('60', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.8, eta=0.3, gamma=1, max_depth=10, max_leaves=7, n_estimators=10, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0, reg_lambda=0.5208333333333334, subsample=1, tree_method='auto'))],
#                verbose=False)), ('31', Pipeline(memory=None,
#                steps=[('truncatedsvdwrapper',
#                        TruncatedSVDWrapper(n_components=0.95, random_state=None)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(boosting_type='gbdt', colsample_bytree=0.4955555555555555, learning_rate=0.08947473684210526, max_bin=150, max_depth=9, min_child_weight=5, min_data_in_leaf=1e-05, min_split_gain=0.05263157894736842, n_estima...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None, reg_alpha=0.631578947368421, reg_lambda=0.15789473684210525, subsample=0.9405263157894738))],
#                verbose=False))],
#       weights=[0.07692307692307693, 0.15384615384615385, 0.15384615384615385, 0.07692307692307693, 0.07692307692307693, 0.15384615384615385, 0.15384615384615385, 0.15384615384615385],
#       flatten_transform=None,
#       classification_labels=array([0, 1])
#   ))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_8b52c32c_edac_11eb_917a_815e38c6bb71row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_8b52c32c_edac_11eb_917a_815e38c6bb71row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b52c32c_edac_11eb_917a_815e38c6bb71row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8b52c32c_edac_11eb_917a_815e38c6bb71row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_8b52c32c_edac_11eb_917a_815e38c6bb71" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b52c32c_edac_11eb_917a_815e38c6bb71level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8b52c32c_edac_11eb_917a_815e38c6bb71row0_col0" class="data row0 col0" >29040</td>
#                         <td id="T_8b52c32c_edac_11eb_917a_815e38c6bb71row0_col1" class="data row0 col1" >218</td>
#             </tr>
#             <tr>
#                         <th id="T_8b52c32c_edac_11eb_917a_815e38c6bb71level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8b52c32c_edac_11eb_917a_815e38c6bb71row1_col0" class="data row1 col0" >734</td>
#                         <td id="T_8b52c32c_edac_11eb_917a_815e38c6bb71row1_col1" class="data row1 col1" >2958</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 91e31822-b86c-44dc-928f-ef49599b7db7,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourceGroups/aml-quickstarts-152512/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-152512/PipelineRuns/PipelineSubmit/91e31822-b86c-44dc-928f-ef49599b7db7)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  a6d5d07b-b433-4fa2-b830-064798b83d67

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

every_12_hours = ScheduleRecurrence(frequency="Hour", interval=12)
pipeline_schedule = Schedule.create(ws, name="Recurrent Training 12hrs",
                                    description="Trains the model every 12 hours",
                                    pipeline_id = published_pipeline.id,
                                    experiment_name="Recurring_Training",
                                    recurrence=every_12_hours)
